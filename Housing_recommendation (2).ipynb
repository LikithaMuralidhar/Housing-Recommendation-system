# %% [markdown]
# Importing the required libraries for the algorithm.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

import os
for dirname, _, filenames in os.walk('C:/Users/muralidhar.l/Downloads/Housing Recommendation'):
    for filename in filenames:
        print(os.path.join(dirname,filename))

# %% [markdown]
# Importing the CSV file

# %%
Housing = pd.read_csv('/Housing recommendation.csv')
Housing.head()
# Out:
#    S.No  Zip Code                         Address  Bedrooms  Bath Laundry  \
# 0     1      2446           77walnut st,Brookline         2   1.0     Yes
# 1     2      2130  21, Forest hill,Jamaican plain         5   2.0     Yes
# 2     3      2116            1197 Boylston street         2   1.0     Yes
# 3     4      2116     1175 Boylston street,Boston         3   1.5     Yes
# 4     5      2215           252 park drive,fenwey         2   1.0     Yes
#
#                                       Transportation  Dist.from_univ   \
# 0  3mins to Dline,5mins walk e line, 10mins to bu...              1.0
# 1          3mins to busstop,9mins walk to green line              1.1
# 2       10mins walk to NEU, 5mins walk to green line              0.4
# 3  Redeye accessable,12mins to NEU, 5mins walk to...              0.6
# 4  Redeye,0.2 mile to green line,o0.1miles to bus...              0.7
#
#                                            Amenities type_of_room  \
# ...

# %% [markdown]
# Reading the Housing recommendation file

# %%
Housing=Housing.dropna(axis=1, how='all')
Housing.head()
# Out:
#    S.No  Zip Code                         Address  Bedrooms  Bath Laundry  \
# 0     1      2446           77walnut st,Brookline         2   1.0     Yes
# 1     2      2130  21, Forest hill,Jamaican plain         5   2.0     Yes
# 2     3      2116            1197 Boylston street         2   1.0     Yes
# 3     4      2116     1175 Boylston street,Boston         3   1.5     Yes
# 4     5      2215           252 park drive,fenwey         2   1.0     Yes
#
#                                       Transportation  Dist.from_univ   \
# 0  3mins to Dline,5mins walk e line, 10mins to bu...              1.0
# 1          3mins to busstop,9mins walk to green line              1.1
# 2       10mins walk to NEU, 5mins walk to green line              0.4
# 3  Redeye accessable,12mins to NEU, 5mins walk to...              0.6
# 4  Redeye,0.2 mile to green line,o0.1miles to bus...              0.7
#
#                                            Amenities type_of_room  \
# ...

# %%
Housing=Housing.dropna(axis=0, how='all')

# %% [markdown]
# Dropping all the columns and rows which are not required

# %%
print(Housing['Dist.from_univ '])
# Out:
# 0     1.0
# 1     1.1
# 2     0.4
# 3     0.6
# 4     0.7
#      ...
# 67    0.5
# 68    0.2
# 69    0.8
# 70    0.3
# 71    2.0
# Name: Dist.from_univ , Length: 72, dtype: float64

# %%
Housing['rent'] = Housing['rent'].str.extract(r'(\d+)').astype(float)

# %% [markdown]
# Removing all the strings from the rent column

# %%
Housing.head()
# Out:
#    S.No  Zip Code                         Address  Bedrooms  Bath Laundry  \
# 0     1      2446           77walnut st,Brookline         2   1.0     Yes
# 1     2      2130  21, Forest hill,Jamaican plain         5   2.0     Yes
# 2     3      2116            1197 Boylston street         2   1.0     Yes
# 3     4      2116     1175 Boylston street,Boston         3   1.5     Yes
# 4     5      2215           252 park drive,fenwey         2   1.0     Yes
#
#                                       Transportation  Dist.from_univ   \
# 0  3mins to Dline,5mins walk e line, 10mins to bu...              1.0
# 1          3mins to busstop,9mins walk to green line              1.1
# 2       10mins walk to NEU, 5mins walk to green line              0.4
# 3  Redeye accessable,12mins to NEU, 5mins walk to...              0.6
# 4  Redeye,0.2 mile to green line,o0.1miles to bus...              0.7
#
#                                            Amenities type_of_room  \
# ...

# %%
Label_encoders = {}
categorical_column = ['Laundry','type_of_room', 'Gender','Food','Type_of_accomodation']
for col in categorical_column:
    le = LabelEncoder()
    Housing[col] = le.fit_transform(Housing[col])
    Label_encoders[col] = le

# %% [markdown]
# Using label encoding method for data preprocessing , here the data of all categorigal column are coverted into 1's and 0's.

# %%
Housing.head()
# Out:
#    S.No  Zip Code                         Address  Bedrooms  Bath  Laundry  \
# 0     1      2446           77walnut st,Brookline         2   1.0        0
# 1     2      2130  21, Forest hill,Jamaican plain         5   2.0        0
# 2     3      2116            1197 Boylston street         2   1.0        0
# 3     4      2116     1175 Boylston street,Boston         3   1.5        0
# 4     5      2215           252 park drive,fenwey         2   1.0        0
#
#                                       Transportation  Dist.from_univ   \
# 0  3mins to Dline,5mins walk e line, 10mins to bu...              1.0
# 1          3mins to busstop,9mins walk to green line              1.1
# 2       10mins walk to NEU, 5mins walk to green line              0.4
# 3  Redeye accessable,12mins to NEU, 5mins walk to...              0.6
# 4  Redeye,0.2 mile to green line,o0.1miles to bus...              0.7
#
#                                            Amenities  type_of_room  \
# ...

# %%
scaler = MinMaxScaler()
numerical_columns = ['Bedrooms','Bath','Dist.from_univ ','rent']
Housing_new= scaler.fit_transform(Housing[numerical_columns])

# %% [markdown]
# Data are scaled based on min and max values of the column  in the range [0,1]

# %%
from sklearn.neighbors import NearestNeighbors

feature_columns = numerical_columns + categorical_column
feature_matrix = Housing[feature_columns].to_numpy()


knn_model = NearestNeighbors(n_neighbors=6, metric='cosine')
knn_model.fit(feature_matrix)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=6)

# %% [markdown]
# Here the feature column is the sum of numerical column and categorical column, These feature column are converted into numpy array and stored in feature matrix
# Here the algorithm model we have used is KNN model.
# It creats a model for finding nearest neighbors for the data set
# The model finds 6 nearest neighbor and the metric used is cossine similarity
# The feature matrix is fit into the KNN

# %%
feature_matrix.shape
# Out:
# (72, 9)

# %%
Housing.head()
# Out:
#    S.No  Zip Code                         Address  Bedrooms  Bath  Laundry  \
# 0     1      2446           77walnut st,Brookline         2   1.0        0
# 1     2      2130  21, Forest hill,Jamaican plain         5   2.0        0
# 2     3      2116            1197 Boylston street         2   1.0        0
# 3     4      2116     1175 Boylston street,Boston         3   1.5        0
# 4     5      2215           252 park drive,fenwey         2   1.0        0
#
#                                       Transportation  Dist.from_univ   \
# 0  3mins to Dline,5mins walk e line, 10mins to bu...              1.0
# 1          3mins to busstop,9mins walk to green line              1.1
# 2       10mins walk to NEU, 5mins walk to green line              0.4
# 3  Redeye accessable,12mins to NEU, 5mins walk to...              0.6
# 4  Redeye,0.2 mile to green line,o0.1miles to bus...              0.7
#
#                                            Amenities  type_of_room  \
# ...

# %%
def recomendation(**kwargs):


    filtered_df = Housing.copy()


    for col in Housing.select_dtypes(include=['object']).columns:
        Housing[col] = Housing[col].str.strip().str.lower()
    kwargs = {k: (v.strip().lower() if isinstance(v, str) else v) for k, v in kwargs.items()}

    for key, value in kwargs.items():
        if value is not None:
            if key not in Housing.columns:
                return f"Error: Column '{key}' not found in dataset."
            filtered_df = filtered_df[filtered_df[key] == value]

    if filtered_df.empty:
        return "No recommendations available for the given criteria."

    index = filtered_df.index[0]


    distances, indices = knn_model.kneighbors(feature_matrix[index].reshape(1, -1))


    recommendations = [Housing.iloc[i] for i in indices[0][1:7]]
    recommendation_df = pd.DataFrame(recommendations)[['Address', 'Zip Code','Transportation','Amenities']]
    result = []
    for idx, row in recommendation_df.iterrows():
        result.append(
            f"{idx + 1}. Address: {row['Address']}\n"
            f"   Zip Code: {row['Zip Code']}\n"
            f"   Transportation: {row['Transportation']}\n"
            f"   Amenities: {row['Amenities']}\n"
        )

    return "\n".join(result)

# %% [markdown]
# Defining the recomendation funtion
# Used *kwargs argument to take any no of user attributes
# It will take the user input only if the user attributes matches the coulumns ins the data , other wise it gives there is no recomendation for the criteria
# It queries the KNN model to get a nearest neighbors
# Fetches recomendation for 6 nearest neighbors

# %%
print(recomendation(Bedrooms = 3,Bath = 1,Food = 1))
# Out:
# 24. Address: 3270 washington street boston
#    Zip Code: 2129
#    Transportation: 4-5 mins walk to stony brook and green street t station (orange line) 0 mins train ride to neu and 20 mins train ride to suffolk university
#    Amenities: it’s a super spacious apartment
# the house is equipped with a centralised ac, stove, oven, heater, air fryer.
#
# 15. Address: mission main apartments,smith street,mission main
#    Zip Code: 2120
#    Transportation: 5mins to orange line, 8mins to green line, red eye accessible
#    Amenities: fully equipped kitchen,heat and hotwater, no pest or rats
#
# 27. Address: 1789 commonwealth ave., #3, (brighton)
#    Zip Code: 2215
#    Transportation: 15 min drive to northeastern university (3.8 miles)
# • chiswick road tram station (green line) right opposite to the unit.
# • bus stand within 0.2 miles and one right in front of the unit.
# ...
